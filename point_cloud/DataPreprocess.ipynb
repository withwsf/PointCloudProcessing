# %%
import pandas as pd
import numpy as np
from pandas import Series,DataFrame

# %%
data=pd.read_csv("station2_label_front.txt")

# %%
data
# Out:
#         -5.745000  16.014999  -1.555000  9.000000
# 0          -5.745  16.016001     -1.566         9
# 1          -5.743  16.011999     -1.562         9
# 2          -5.743  16.017000     -1.550         9
# 3          -5.736  16.011000     -1.566         9
# 4          -5.734  16.004000     -1.555         9
# 5          -5.734  16.009001     -1.561         9
# 6          -5.733  15.983000     -1.570         9
# 7          -5.731  16.016001     -1.567         9
# 8          -5.731  16.020000     -1.563         9
# 9          -5.730  15.998000     -1.571         9
# 10         -5.729  16.014000     -1.573         9
# 11         -5.727  15.966000     -1.586         9
# 12         -5.727  15.986000     -1.576         9
# 13         -5.726  15.962000     -1.580         9
# 14         -5.725  15.957000     -1.573         9
# 15         -5.722  15.953000     -1.591         9
# 16         -5.722  16.011999     -1.566         9
# 17         -5.721  15.990000     -1.577         9
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 518482 entries, 0 to 518481
# Data columns (total 4 columns):
# -5.745000    518482 non-null float64
# 16.014999    518482 non-null float64
# -1.555000    518482 non-null float64
# 9.000000     518482 non-null float64
# dtypes: float64(4)
# memory usage: 19.8 MB

# %%
data.describe()
# Out:
#            -5.745000      16.014999      -1.555000       9.000000
# count  518482.000000  518482.000000  518482.000000  518482.000000
# mean       -1.786923      16.129483       0.122075       5.527721
# std         1.777820       1.093932       1.472509       2.201122
# min        -5.745000      13.617000      -2.016000       1.000000
# 25%        -3.288000      15.549000      -1.313000       5.000000
# 50%        -1.437000      16.205999       0.064000       5.000000
# 75%        -0.323000      16.858999       1.235000       6.000000
# max         1.468000      19.306000       3.823000       9.000000
